# %% [markdown]
# # Task 1 - DataFrame manipulation
#
# Using states_covid.csv, we are going to read the data in as a DataFrame to manipulate, subset, and filter in various ways.
#
# ## Task 1.1
#
# Read in states_covid.csv with date as a "date" dtype, and only columns consisting of the hospitalization (4 col), ICU (2 col), and Ventilators (2 col)

# %%
import os
import numpy as np
import pandas as pd

# %%
cd Desktop/DrAllen_Biol792
# Out:
# [Errno 2] No such file or directory: 'Desktop/DrAllen_Biol792'
# /Users/erickarkay/Desktop/Julies_Class

# %%
ls
# Out:
# Bloom_etal_2018_Reduced_Dataset.csv  Kay_E_HW4.md
# EK_HW4.webarchive                    Kay_E_HW4.tex
# HW_3.txt                             ggplot/
# Julie_HW_wk1/                        logfiles/
# Kay_E_HW1.docx                       scripts/
# Kay_E_HW1.txt                        shell key points .pdf
# Kay_E_HW2.txt                        shell-lesson-data/
# Kay_E_HW3.ipynb                      shell-lesson-data.zip
# Kay_E_HW4.ipynb                      states_covid.csv

# %%
state_covid_df = pd.read_csv("states_covid.csv")

# %%
state_covid_df.head()
# Out:
#          date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0  2021-02-23    AK    290.0             NaN              0            NaN
# 1  2021-02-23    AL   9660.0          7575.0             68         2085.0
# 2  2021-02-23    AR   5377.0          4321.0             14         1056.0
# 3  2021-02-23    AS      0.0             NaN              0            NaN
# 4  2021-02-23    AZ  15650.0         13821.0            148         1829.0
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0        1260.0                  1260.0                   38.0
# 1       45250.0                 45250.0                  762.0
# 2       14617.0                 14617.0                  545.0
# 3           NaN                     NaN                    NaN
# 4       57072.0                 57072.0                 1515.0
#
#    hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# ...

# %%
new_covid_df = state_covid_df[['date', 'state','hospitalized', 'hospitalizedCumulative', 'hospitalizedCurrently', 'hospitalizedIncrease','inIcuCurrently','inIcuCumulative','onVentilatorCurrently', 'onVentilatorCumulative']]

# %%
new_covid_df.head()
# Out:
#          date state  hospitalized  hospitalizedCumulative  \
# 0  2021-02-23    AK        1260.0                  1260.0
# 1  2021-02-23    AL       45250.0                 45250.0
# 2  2021-02-23    AR       14617.0                 14617.0
# 3  2021-02-23    AS           NaN                     NaN
# 4  2021-02-23    AZ       57072.0                 57072.0
#
#    hospitalizedCurrently  hospitalizedIncrease  inIcuCurrently  \
# 0                   38.0                     9             NaN
# 1                  762.0                   122             NaN
# 2                  545.0                    47           204.0
# 3                    NaN                     0             NaN
# 4                 1515.0                    78           447.0
#
#    inIcuCumulative  onVentilatorCurrently  onVentilatorCumulative
# 0              NaN                    5.0                     NaN
# 1           2632.0                    NaN                  1497.0
# ...

# %%
new_covid_df['date'] = pd.to_datetime(new_covid_df['date'],yearfirst=True) 
new_covid_df.dtypes
# Out:
# <ipython-input-41-f7119624ae56>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_covid_df['date'] = pd.to_datetime(new_covid_df['date'],yearfirst=True)
# date                      datetime64[ns]
# state                                |S2
# hospitalized                     float64
# hospitalizedCumulative           float64
# hospitalizedCurrently            float64
# hospitalizedIncrease               int64
# inIcuCurrently                   float64
# inIcuCumulative                  float64
# onVentilatorCurrently            float64
# onVentilatorCumulative           float64
# dtype: object

# %%
new_covid_df['state'] = new_covid_df['state'].astype("|S")
# Out:
# <ipython-input-11-ed37d5e594ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_covid_df['state'] = new_covid_df['state'].astype("|S")

# %%
new_covid_df.dtypes
# Out:
# date                      datetime64[ns]
# state                                |S2
# hospitalized                     float64
# hospitalizedCumulative           float64
# hospitalizedCurrently            float64
# hospitalizedIncrease               int64
# inIcuCurrently                   float64
# inIcuCumulative                  float64
# onVentilatorCurrently            float64
# onVentilatorCumulative           float64
# dtype: object

# %%
display(new_covid_df)
# Out:
#             date  state  hospitalized  hospitalizedCumulative  \
# 0     2021-02-23  b'AK'        1260.0                  1260.0
# 1     2021-02-23  b'AL'       45250.0                 45250.0
# 2     2021-02-23  b'AR'       14617.0                 14617.0
# 3     2021-02-23  b'AS'           NaN                     NaN
# 4     2021-02-23  b'AZ'       57072.0                 57072.0
# ...          ...    ...           ...                     ...
# 20103 2020-01-17  b'WA'           NaN                     NaN
# 20104 2020-01-16  b'WA'           NaN                     NaN
# 20105 2020-01-15  b'WA'           NaN                     NaN
# 20106 2020-01-14  b'WA'           NaN                     NaN
# 20107 2020-01-13  b'WA'           NaN                     NaN
#
#        hospitalizedCurrently  hospitalizedIncrease  inIcuCurrently  \
# 0                       38.0                     9             NaN
# 1                      762.0                   122             NaN
# ...

# %% [markdown]
# ## Task 1.2
#
# For each of the following catergories: currently hospitalized, currently in the ICU, and currently on ventilation...
# Find the 5 states with the greatest numbers in each catergory and list them in order.
# hint: sort_values, unique

# %%
current_hosp = new_covid_df.groupby('state').max('hospitalizedCurrently')

# %%
current_hosp.head(10)
# Out:
#        hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# state
# b'AK'        1260.0                  1260.0                  166.0
# b'AL'       45250.0                 45250.0                 3088.0
# b'AR'       14617.0                 14617.0                 1371.0
# b'AS'           NaN                     NaN                    NaN
# b'AZ'       57072.0                 57072.0                 5082.0
# b'CA'           NaN                     NaN                22851.0
# b'CO'       23293.0                 23293.0                 1995.0
# b'CT'       13793.0                 13793.0                 1972.0
# b'DC'           NaN                     NaN                  447.0
# b'DE'           NaN                     NaN                  474.0
#
#        hospitalizedIncrease  inIcuCurrently  inIcuCumulative  \
# state
# b'AK'                    34             NaN              NaN
# b'AL'                  3656             NaN           2632.0
# ...

# %%
current_hosp.sort_values(['hospitalizedCurrently'], ascending = (False))
# Out:
#        hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# state
# b'CA'           NaN                     NaN                22851.0
# b'NY'       89995.0                 89995.0                18825.0
# b'TX'           NaN                     NaN                14218.0
# b'FL'       79410.0                 79410.0                 9520.0
# b'NJ'       63190.0                 63190.0                 8270.0
# b'PA'        1145.0                  1145.0                 6346.0
# b'IL'           NaN                     NaN                 6175.0
# b'GA'       55167.0                 55167.0                 6108.0
# b'OH'       49651.0                 49651.0                 5296.0
# b'AZ'       57072.0                 57072.0                 5082.0
# b'MI'           NaN                     NaN                 4326.0
# b'NC'           NaN                     NaN                 3990.0
# b'MA'       19176.0                 19176.0                 3977.0
# ...

# %% [markdown]
# Currently hosptiilizied ANSWER: CA, NY, TX, FL, NJ

# %%
current_ICU = new_covid_df.groupby('state').max('inIcuCurrently')

# %%
current_ICU.head(10)
# Out:
#        hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# state
# b'AK'        1260.0                  1260.0                  166.0
# b'AL'       45250.0                 45250.0                 3088.0
# b'AR'       14617.0                 14617.0                 1371.0
# b'AS'           NaN                     NaN                    NaN
# b'AZ'       57072.0                 57072.0                 5082.0
# b'CA'           NaN                     NaN                22851.0
# b'CO'       23293.0                 23293.0                 1995.0
# b'CT'       13793.0                 13793.0                 1972.0
# b'DC'           NaN                     NaN                  447.0
# b'DE'           NaN                     NaN                  474.0
#
#        hospitalizedIncrease  inIcuCurrently  inIcuCumulative  \
# state
# b'AK'                    34             NaN              NaN
# b'AL'                  3656             NaN           2632.0
# ...

# %%
current_ICU.sort_values(['inIcuCurrently'], ascending = (False))
# Out:
#        hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# state
# b'NY'       89995.0                 89995.0                18825.0
# b'CA'           NaN                     NaN                22851.0
# b'TX'           NaN                     NaN                14218.0
# b'NJ'       63190.0                 63190.0                 8270.0
# b'MI'           NaN                     NaN                 4326.0
# b'OH'       49651.0                 49651.0                 5296.0
# b'IL'           NaN                     NaN                 6175.0
# b'PA'        1145.0                  1145.0                 6346.0
# b'AZ'       57072.0                 57072.0                 5082.0
# b'MA'       19176.0                 19176.0                 3977.0
# b'IN'       42557.0                 42557.0                 3460.0
# b'NC'           NaN                     NaN                 3990.0
# b'TN'       18363.0                 18363.0                 3554.0
# ...

# %% [markdown]
# CURRENTLY IN ICU ANSWER: NY, CA, TX, NY, NJ, MI

# %%
current_vent = new_covid_df.groupby('state').max('onVentilatorCurrently')

# %%
current_vent.head(10)
# Out:
#        hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# state
# b'AK'        1260.0                  1260.0                  166.0
# b'AL'       45250.0                 45250.0                 3088.0
# b'AR'       14617.0                 14617.0                 1371.0
# b'AS'           NaN                     NaN                    NaN
# b'AZ'       57072.0                 57072.0                 5082.0
# b'CA'           NaN                     NaN                22851.0
# b'CO'       23293.0                 23293.0                 1995.0
# b'CT'       13793.0                 13793.0                 1972.0
# b'DC'           NaN                     NaN                  447.0
# b'DE'           NaN                     NaN                  474.0
#
#        hospitalizedIncrease  inIcuCurrently  inIcuCumulative  \
# state
# b'AK'                    34             NaN              NaN
# b'AL'                  3656             NaN           2632.0
# ...

# %%
current_vent.sort_values(['onVentilatorCurrently'], ascending = (False))
# Out:
#        hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# state
# b'NY'       89995.0                 89995.0                18825.0
# b'NJ'       63190.0                 63190.0                 8270.0
# b'MI'           NaN                     NaN                 4326.0
# b'OH'       49651.0                 49651.0                 5296.0
# b'AZ'       57072.0                 57072.0                 5082.0
# b'IL'           NaN                     NaN                 6175.0
# b'PA'        1145.0                  1145.0                 6346.0
# b'LA'           NaN                     NaN                 2134.0
# b'TN'       18363.0                 18363.0                 3554.0
# b'IN'       42557.0                 42557.0                 3460.0
# b'MO'           NaN                     NaN                 2862.0
# b'VA'       23698.0                 23698.0                 3209.0
# b'WI'       25838.0                 25838.0                 2278.0
# ...

# %% [markdown]
# Currently on ventilator answer: NY, NJ, MI, OH, AZ

# %% [markdown]
# ### Task 1.3
#
# Find the date in which each state crossed 1000 cumulative hospitilized covid patients

# %%
cum_hosp_df = new_covid_df[(new_covid_df.hospitalizedCumulative > 1000)]

# %% [markdown]
# ### I found multiple ways to group DF by state and minimum hosptilized cumalitive, but NONE of them included the date.

# %%
cum_hosp_df.groupby('state').min('hospitalizedCumulative')
# Out:
#        hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# state
# b'AK'        1004.0                  1004.0                   32.0
# b'AL'        1008.0                  1008.0                  420.0
# b'AR'        1003.0                  1003.0                  206.0
# b'AZ'        1037.0                  1037.0                  468.0
# b'CO'        1079.0                  1079.0                  211.0
# b'CT'        7758.0                  7758.0                   42.0
# b'FL'        1123.0                  1123.0                 2005.0
# b'GA'        1056.0                  1056.0                  783.0
# b'HI'        1001.0                  1001.0                   37.0
# b'ID'        1006.0                  1006.0                  105.0
# b'IN'        4389.0                  4389.0                  595.0
# b'KS'        1011.0                  1011.0                  140.0
# b'KY'        1008.0                  1008.0                  263.0
# ...

# %%
cum_hosp_df.groupby('state')['hospitalizedCumulative'].agg([min])
# Out:
#            min
# state
# b'AK'   1004.0
# b'AL'   1008.0
# b'AR'   1003.0
# b'AZ'   1037.0
# b'CO'   1079.0
# b'CT'   7758.0
# b'FL'   1123.0
# b'GA'   1056.0
# b'HI'   1001.0
# b'ID'   1006.0
# b'IN'   4389.0
# b'KS'   1011.0
# b'KY'   1008.0
# b'MA'   1370.0
# b'MD'   1059.0
# b'ME'   1015.0
# b'MN'   1044.0
# b'MS'   1001.0
# b'MT'   1001.0
# b'ND'   1016.0
# b'NE'   1029.0
# b'NH'   1007.0
# b'NJ'  16373.0
# b'NM'   1139.0
# b'NY'   1531.0
# b'OH'   1006.0
# b'OK'   1003.0
# b'OR'   1006.0
# b'PA'   1004.0
# b'RI'   1013.0
# b'SC'   1110.0
# b'SD'   1006.0
# b'TN'   1013.0
# b'UT'   1012.0
# b'VA'   1048.0
# b'WA'   3125.0
# b'WI'   1049.0
# b'WY'   1001.0

# %%
cum_hosp_df.groupby('state').agg({'hospitalizedCumulative': ['min']})
# Out:
#       hospitalizedCumulative
#                          min
# state
# b'AK'                 1004.0
# b'AL'                 1008.0
# b'AR'                 1003.0
# b'AZ'                 1037.0
# b'CO'                 1079.0
# b'CT'                 7758.0
# b'FL'                 1123.0
# b'GA'                 1056.0
# b'HI'                 1001.0
# b'ID'                 1006.0
# b'IN'                 4389.0
# b'KS'                 1011.0
# b'KY'                 1008.0
# b'MA'                 1370.0
# b'MD'                 1059.0
# b'ME'                 1015.0
# b'MN'                 1044.0
# b'MS'                 1001.0
# b'MT'                 1001.0
# b'ND'                 1016.0
# b'NE'                 1029.0
# b'NH'                 1007.0
# b'NJ'                16373.0
# b'NM'                 1139.0
# b'NY'                 1531.0
# b'OH'                 1006.0
# b'OK'                 1003.0
# b'OR'                 1006.0
# b'PA'                 1004.0
# b'RI'                 1013.0
# ...

# %%
cum_hosp_df.groupby('state').min('hospitalizedCumulative')
# Out:
#        hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# state
# b'AK'        1004.0                  1004.0                   32.0
# b'AL'        1008.0                  1008.0                  420.0
# b'AR'        1003.0                  1003.0                  206.0
# b'AZ'        1037.0                  1037.0                  468.0
# b'CO'        1079.0                  1079.0                  211.0
# b'CT'        7758.0                  7758.0                   42.0
# b'FL'        1123.0                  1123.0                 2005.0
# b'GA'        1056.0                  1056.0                  783.0
# b'HI'        1001.0                  1001.0                   37.0
# b'ID'        1006.0                  1006.0                  105.0
# b'IN'        4389.0                  4389.0                  595.0
# b'KS'        1011.0                  1011.0                  140.0
# b'KY'        1008.0                  1008.0                  263.0
# ...

# %% [markdown]
# ### below includes date column but I do NOT understand how hosptilizedCumalitize is what the 'min' funciton is acting on since i did not specify it. I have spent hours on this and am walking away confused and frustrated.

# %%
cum_hosp_df.groupby('state').agg('min')
# Out:
#             date  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# state
# b'AK' 2020-12-29        1004.0                  1004.0                   32.0
# b'AL' 2020-05-01        1008.0                  1008.0                  420.0
# b'AR' 2020-06-15        1003.0                  1003.0                  206.0
# b'AZ' 2020-04-11        1037.0                  1037.0                  468.0
# b'CO' 2020-04-07        1079.0                  1079.0                  211.0
# b'CT' 2020-05-01        7758.0                  7758.0                   42.0
# b'FL' 2020-04-02        1123.0                  1123.0                 2005.0
# b'GA' 2020-04-02        1056.0                  1056.0                  783.0
# b'HI' 2020-10-18        1001.0                  1001.0                   37.0
# b'ID' 2020-08-11        1006.0                  1006.0                  105.0
# b'IN' 2020-05-08        4389.0                  4389.0                  595.0
# ...

# %%
cum_hosp_df
# Out:
#             date  state  hospitalized  hospitalizedCumulative  \
# 0     2021-02-23  b'AK'        1260.0                  1260.0
# 1     2021-02-23  b'AL'       45250.0                 45250.0
# 2     2021-02-23  b'AR'       14617.0                 14617.0
# 4     2021-02-23  b'AZ'       57072.0                 57072.0
# 6     2021-02-23  b'CO'       23293.0                 23293.0
# ...          ...    ...           ...                     ...
# 18797 2020-03-25  b'NY'        5126.0                  5126.0
# 18853 2020-03-24  b'NY'        4041.0                  4041.0
# 18909 2020-03-23  b'NY'        3125.0                  3125.0
# 18965 2020-03-22  b'NY'        2354.0                  2354.0
# 19021 2020-03-21  b'NY'        1531.0                  1531.0
#
#        hospitalizedCurrently  hospitalizedIncrease  inIcuCurrently  \
# 0                       38.0                     9             NaN
# 1                      762.0                   122             NaN
# ...

# %% [markdown]
# ### playing with code to figure out why it works how it does

# %%
df = new_covid_df[['date', 'state','hospitalizedCurrently', 'hospitalizedIncrease','inIcuCurrently','inIcuCumulative','onVentilatorCurrently', 'onVentilatorCumulative']]

# %%
df.groupby('state').agg('min')
# Out:
#             date  hospitalizedCurrently  hospitalizedIncrease  inIcuCurrently  \
# state
# b'AK' 2020-03-06                    7.0                     0             NaN
# b'AL' 2020-03-07                   74.0                     0             NaN
# b'AR' 2020-03-06                   13.0                   -18           160.0
# b'AS' 2020-03-16                    NaN                     0             NaN
# b'AZ' 2020-03-04                  468.0                 -2316           114.0
# b'CA' 2020-03-04                  746.0                     0           200.0
# b'CO' 2020-03-04                   56.0                   -13             NaN
# b'CT' 2020-02-29                   42.0                 -4124             NaN
# b'DC' 2020-03-05                   69.0                     0            17.0
# b'DE' 2020-03-06                   11.0                     0             4.0
# b'FL' 2020-01-29                 2005.0                     0             NaN
# ...

# %% [markdown]
# ## Task 2 - DataFrame summarizing
#
# Using Bloom_etal_2018_Reduced_Dataset.csv, we are going to do more dataframe manipulation and subsetting and summarizing
#
# ### Task 2.1
#
# Read in Bloom_etal_2018_Reduced_Dataset.csv and create two new columns ('genus','species') that consists of the column taxa split at the underscore. Print out the head of this new dataframe and the number of unique genera**
#
# hint: pd.str.split(,expand=True)
#
# for example:
#
# taxa	genus	species
# Alosa_alabamae	Alosa	alabamae

# %%
bloom_df = pd.read_csv('Bloom_etal_2018_Reduced_Dataset.csv')

# %%
bloom_df.head()
# Out:
#                    taxa  logbodysize  trophic_position         Reg
# 0        Alosa_alabamae     1.707570          0.431364  diadromous
# 1           Alosa_alosa     1.778151          0.556303  diadromous
# 2          Alosa_fallax     1.778151          0.556303  diadromous
# 3       Alosa_mediocris     1.778151          0.612784  diadromous
# 4  Alosa_pseudoharengus     1.602060          0.544068  diadromous

# %%
bloom_df.at[49, 'taxa'] = 'Thryssa_dussumieri'

# %% [markdown]
# above code fixes an error in a single cell that is index number 49 in taxa column

# %%
bloom_df[['Genus', 'Species']] = bloom_df['taxa'].str.split('_', expand=True)

# %%
bloom_df.head()
# Out:
#                    taxa  logbodysize  trophic_position         Reg  Genus  \
# 0        Alosa_alabamae     1.707570          0.431364  diadromous  Alosa
# 1           Alosa_alosa     1.778151          0.556303  diadromous  Alosa
# 2          Alosa_fallax     1.778151          0.556303  diadromous  Alosa
# 3       Alosa_mediocris     1.778151          0.612784  diadromous  Alosa
# 4  Alosa_pseudoharengus     1.602060          0.544068  diadromous  Alosa
#
#           Species
# 0        alabamae
# 1           alosa
# 2          fallax
# 3       mediocris
# 4  pseudoharengus

# %%
bloom_df['Genus'].value_counts()
# Out:
# Anchoa            7
# Alosa             6
# Anchoviella       5
# Pellonula         2
# Potamalosa        1
# Chirocentrodon    1
# Sundasalanx       1
# Hilsa             1
# Cetengraulis      1
# Clupeoides        1
# Anodontostoma     1
# Thryssa           1
# Coilia            1
# Microthrissa      1
# Escualosa         1
# Stolothrissa      1
# Tenualosa         1
# Amazonsprattus    1
# Rhinosardinia     1
# Engraulis         1
# Encrasicholina    1
# Ethmalosa         1
# Hyperlophus       1
# Gilchristella     1
# Jenkinsia         1
# Stolephorus       1
# Clupeichthys      1
# Sierrathrissa     1
# Sauvagella        1
# Anchovia          1
# Spratelloides     1
# Ehirava           1
# Pellona           1
# Ramnogaster       1
# Name: Genus, dtype: int64

# %%
cnt = 0
visited = []
for i in range(0, len(bloom_df['Genus'])):
        if bloom_df['Genus'][i] not in visited:
                visited.append(bloom_df['Genus'][i])
                cnt += 1
print("Number of unique genera :",
      cnt)
print("unique values :",
     visited)
# Out:
# Number of unique genera : 34
# unique values : ['Alosa', 'Amazonsprattus', 'Anchoa', 'Anchovia', 'Anchoviella', 'Anodontostoma', 'Cetengraulis', 'Chirocentrodon', 'Clupeichthys', 'Clupeoides', 'Coilia', 'Ehirava', 'Encrasicholina', 'Engraulis', 'Escualosa', 'Ethmalosa', 'Gilchristella', 'Hilsa', 'Hyperlophus', 'Jenkinsia', 'Microthrissa', 'Pellona', 'Pellonula', 'Potamalosa', 'Ramnogaster', 'Rhinosardinia', 'Sauvagella', 'Sierrathrissa', 'Spratelloides', 'Stolephorus', 'Stolothrissa', 'Sundasalanx', 'Tenualosa', 'Thryssa']

# %% [markdown]
# ### Task 2.2
#
# Create a new dataframe with the mean logbodysize and trophicposition of each genera. Sort this data frame by the largest body size. Print the head of this dataframe.

# %%
mean_df = bloom_df.groupby('Genus', as_index=True).agg(['mean'])

# %%
list(mean_df.columns)  # got an error so needed to see what the new column name was for mean logbodysize
# Out:
# [('logbodysize', 'mean'), ('trophic_position', 'mean')]

# %%
mean_df = mean_df.sort_values([('logbodysize', 'mean')], ascending = (False))

# %%
mean_df.head()
# Out:
#            logbodysize trophic_position
#                   mean             mean
# Genus
# Tenualosa     1.778151         0.462398
# Alosa         1.739062         0.540815
# Coilia        1.544068         0.477121
# Ethmalosa     1.544068         0.397940
# Potamalosa    1.505150         0.518514

# %% [markdown]
# Which genera is the smallest and largest?

# %% [markdown]
# smallest is Potamaolsa and largest is Tenualosa

# %% [markdown]
# What is the trophic position of the smallest and largest? smallest is 0.462398 and largest is 0.518514

# %% [markdown]
# ## Task 3 - Read in muliple files to a dictionary and make a DataFrame - OPTIONAL/BONUS
#
# ### This is not something you are expected to do in this course, but just here to give you an idea of the things that you COULD do. Answers will be posted after due date.
#
# Using logfiles: we are going to do read in each file, get some data, append it to a dictionary to later make into a dataframe.
#
# note: make sure to unzip logfiles
